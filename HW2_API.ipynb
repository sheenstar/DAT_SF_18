# %%
import json
import urllib
import pandas as pd

import requests
import json

api = 'https://www.kimonolabs.com/api/cj4g7pne?apikey=FgalHSopVgosmAZPIYTamrCkaUyPjPmm'

# %%
movies = requests.get(api)
movies.text
# Out:
# u'{"name":"IMDB TopRated","count":250,"frequency":"Manual Crawl","version":1,"newdata":true,"lastrunstatus":"success","thisversionstatus":"success","thisversionrun":"Sun Nov 08 2015 02:08:08 GMT+0000 (UTC)","results":{"collection1":[{"Title":{"href":"http://www.imdb.com/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_1","text":"The Shawshank Redemption"},"Year":"(1994)","Rating":"9.2","index":1,"url":"http://www.imdb.com/chart/top?ref_=nv_mv_250_6"},{"Title":{"href":"http://www.imdb.com/title/tt0068646/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_2","text":"The Godfather"},"Year":"(1972)","Rating":"9.2","index":2,"url":"http://www.imdb.com/chart/top?ref_=nv_mv_250_6"},{"Title":{"href":"http://www.imdb.com/title/tt0071562/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center
# ...

# %%
response_dict = json.loads(movies.text)

# %%
response_dict
# Out:
# {u'count': 250,
#  u'frequency': u'Manual Crawl',
#  u'lastrunstatus': u'success',
#  u'name': u'IMDB TopRated',
#  u'newdata': True,
#  u'results': {u'collection1': [{u'Rating': u'9.2',
#     u'Title': {u'href': u'http://www.imdb.com/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_1',
#      u'text': u'The Shawshank Redemption'},
#     u'Year': u'(1994)',
#     u'index': 1,
#     u'url': u'http://www.imdb.com/chart/top?ref_=nv_mv_250_6'},
#    {u'Rating': u'9.2',
#     u'Title': {u'href': u'http://www.imdb.com/title/tt0068646/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_2',
#      u'text': u'The Godfather'},
#     u'Year': u'(1972)',
#     u'index': 2,
#     u'url': u'http://www.imdb.com/chart/top?ref_=nv_mv_250_6'},
#    {u'Rating': u'9.0',
# ...

# %%
print response_dict.keys()
# Out:
# [u'count', u'name', u'lastrunstatus', u'results', u'thisversionstatus', u'thisversionrun', u'frequency', u'version', u'newdata']

# %%
print response_dict['results']
# Out:
# {u'collection1': [{u'url': u'http://www.imdb.com/chart/top?ref_=nv_mv_250_6', u'Rating': u'9.2', u'Year': u'(1994)', u'index': 1, u'Title': {u'text': u'The Shawshank Redemption', u'href': u'http://www.imdb.com/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_1'}}, {u'url': u'http://www.imdb.com/chart/top?ref_=nv_mv_250_6', u'Rating': u'9.2', u'Year': u'(1972)', u'index': 2, u'Title': {u'text': u'The Godfather', u'href': u'http://www.imdb.com/title/tt0068646/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_2'}}, {u'url': u'http://www.imdb.com/chart/top?ref_=nv_mv_250_6', u'Rating': u'9.0', u'Year': u'(1974)', u'index': 3, u'Title': {u'text': u'The Godfather: Part II', u'href': u'http://www.imdb.com/title/tt0071562/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15
# ...

# %%
allkeys = response_dict['results']

# %%
type(allkeys)
# Out:
# dict

# %%
print allkeys.keys()
# Out:
# [u'collection1']

# %%
hopefully = allkeys['collection1']

# %%
type(hopefully)
# Out:
# list

# %%
print hopefully
# Out:
# [{u'url': u'http://www.imdb.com/chart/top?ref_=nv_mv_250_6', u'Rating': u'9.2', u'Year': u'(1994)', u'index': 1, u'Title': {u'text': u'The Shawshank Redemption', u'href': u'http://www.imdb.com/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_1'}}, {u'url': u'http://www.imdb.com/chart/top?ref_=nv_mv_250_6', u'Rating': u'9.2', u'Year': u'(1972)', u'index': 2, u'Title': {u'text': u'The Godfather', u'href': u'http://www.imdb.com/title/tt0068646/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_2'}}, {u'url': u'http://www.imdb.com/chart/top?ref_=nv_mv_250_6', u'Rating': u'9.0', u'Year': u'(1974)', u'index': 3, u'Title': {u'text': u'The Godfather: Part II', u'href': u'http://www.imdb.com/title/tt0071562/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&r
# ...

# %%
print hopefully[0]
# Out:
# {u'url': u'http://www.imdb.com/chart/top?ref_=nv_mv_250_6', u'Rating': u'9.2', u'Year': u'(1994)', u'index': 1, u'Title': {u'text': u'The Shawshank Redemption', u'href': u'http://www.imdb.com/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2239792642&pf_rd_r=0HZ8CBFT73WNCT7XWXF5&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_1'}}

# %%
type(hopefully[0])
# Out:
# dict

# %%
print hopefully[0].keys()
# Out:
# [u'url', u'Rating', u'Year', u'index', u'Title']

# %%
df = pd.DataFrame(hopefully)

# %%
print df
# Out:
#     Rating                                              Title    Year  index  \
# 0      9.2  {u'text': u'The Shawshank Redemption', u'href'...  (1994)      1
# 1      9.2  {u'text': u'The Godfather', u'href': u'http://...  (1972)      2
# 2      9.0  {u'text': u'The Godfather: Part II', u'href': ...  (1974)      3
# 3      8.9  {u'text': u'The Dark Knight', u'href': u'http:...  (2008)      4
# 4      8.9  {u'text': u'12 Angry Men', u'href': u'http://w...  (1957)      5
# 5      8.9  {u'text': u'Schindler's List', u'href': u'http...  (1993)      6
# 6      8.9  {u'text': u'Pulp Fiction', u'href': u'http://w...  (1994)      7
# 7      8.9  {u'text': u'The Good, the Bad and the Ugly', u...  (1966)      8
# 8      8.9  {u'text': u'The Lord of the Rings: The Return ...  (2003)      9
# 9      8.8  {u'text': u'Fight Club', u'href': u'http://www...  (1999)     10
# 10     8.8  {u'text': u'The Lord of the Rings: The Fellows...  (2001)     11
# ...

# %%
hopefully[0].keys() == df.columns
# Out:
# array([False, False,  True,  True, False], dtype=bool)

# %%
df.Year
# Out:
# 0      (1994)
# 1      (1972)
# 2      (1974)
# 3      (2008)
# 4      (1957)
# 5      (1993)
# 6      (1994)
# 7      (1966)
# 8      (2003)
# 9      (1999)
# 10     (2001)
# 11     (1980)
# 12     (1994)
# 13     (2010)
# 14     (1975)
# 15     (2002)
# 16     (1990)
# 17     (1999)
# 18     (1977)
# 19     (1954)
# 20     (2002)
# 21     (1995)
# 22     (1991)
# 23     (1995)
# 24     (1946)
# 25     (1997)
# 26     (1994)
# 27     (1968)
# 28     (2014)
# 29     (1998)
#         ...
# 220    (2014)
# 221    (1995)
# 222    (2008)
# 223    (1952)
# 224    (2010)
# 225    (2014)
# 226    (1964)
# 227    (2003)
# 228    (2013)
# 229    (1946)
# 230    (1986)
# 231    (2011)
# 232    (1953)
# 233    (1966)
# 234    (1973)
# 235    (2003)
# 236    (1991)
# 237    (1955)
# 238    (1959)
# 239    (1954)
# 240    (2004)
# 241    (1967)
# 242    (1967)
# 243    (1961)
# 244    (1960)
# 245    (1962)
# 246    (1994)
# 247    (2000)
# 248    (1951)
# 249    (1972)
# ...

# %%
pd.isnull(df.Year)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 220    False
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# 248    False
# 249    False
# Name: Year, dtype: bool
